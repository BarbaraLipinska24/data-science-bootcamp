# %% [markdown]
# <a href="https://colab.research.google.com/github/BarbaraLipinska24/data-science-bootcamp/blob/main/03_wczytywanie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
def fetch_financial_data(company='AMZN'):

  import pandas_datareader.data as web
  return web.DataReader(name=company, data_source='stooq')

df=fetch_financial_data('UBER')
df.head()
df=df.sort_index()
df.head()
# Out:
#              Open   High    Low  Close     Volume
# Date
# 2019-05-10  42.00  45.00  41.06  41.57  186322536
# 2019-05-13  38.79  39.24  36.08  37.10   79442420
# 2019-05-14  38.31  39.96  36.85  39.96   46661147
# 2019-05-15  39.37  41.88  38.95  41.29   36086065
# 2019-05-16  41.48  44.06  41.25  43.00   38115524

# %% [markdown]
# Zapis/Odczyt danych z pliku CSV

# %%
df.to_csv('Uber.csv')

# %%
df_nov=df[(df.index.month==11)&(df.index.year==2019)]

# %%
df_nov.to_csv('UberNOV.csv')

# %%
new_df=pd.read_csv('UberNOV.csv',index_col=0)

# %%
new_df
# Out:
#              Open   High      Low  Close     Volume
# Date
# 2019-11-01  31.45  31.70  30.7412  31.37   10460430
# 2019-11-04  31.45  31.75  30.1200  31.08   32330121
# 2019-11-05  29.13  29.30  27.9700  28.02   52180615
# 2019-11-06  26.06  27.55  25.5800  26.94  133569790
# 2019-11-07  26.80  27.42  26.4500  27.38   65949472
# 2019-11-08  27.48  27.62  26.9150  27.01   45263118
# 2019-11-11  27.03  27.21  26.2300  27.14   41445732
# 2019-11-12  27.38  27.66  26.6600  26.70   37095389
# 2019-11-13  26.47  26.82  26.1400  26.71   34512663
# 2019-11-14  26.80  26.86  25.6650  25.99   28027875
# 2019-11-15  26.18  26.80  25.9550  26.79   41372771
# 2019-11-18  26.80  27.00  26.3000  26.75   37309667
# 2019-11-19  26.77  27.22  26.6100  27.05   34115865
# 2019-11-20  27.06  28.40  26.9450  28.03   54075774
# 2019-11-21  28.67  29.60  28.5000  29.46   55658629
# 2019-11-22  29.84  30.13  29.2100  29.56   44383876
# 2019-11-25  28.69  29.60  28.3800  29.11   37571611
# ...

# %%
df_nov.to_excel('uberNOV.xlsx')

# %%
new_df=pd.read_excel('uberNOV.xlsx')

# %%
new_df
# Out:
#          Date   Open   High      Low  Close     Volume
# 0  2019-11-01  31.45  31.70  30.7412  31.37   10460430
# 1  2019-11-04  31.45  31.75  30.1200  31.08   32330121
# 2  2019-11-05  29.13  29.30  27.9700  28.02   52180615
# 3  2019-11-06  26.06  27.55  25.5800  26.94  133569790
# 4  2019-11-07  26.80  27.42  26.4500  27.38   65949472
# 5  2019-11-08  27.48  27.62  26.9150  27.01   45263118
# 6  2019-11-11  27.03  27.21  26.2300  27.14   41445732
# 7  2019-11-12  27.38  27.66  26.6600  26.70   37095389
# 8  2019-11-13  26.47  26.82  26.1400  26.71   34512663
# 9  2019-11-14  26.80  26.86  25.6650  25.99   28027875
# 10 2019-11-15  26.18  26.80  25.9550  26.79   41372771
# 11 2019-11-18  26.80  27.00  26.3000  26.75   37309667
# 12 2019-11-19  26.77  27.22  26.6100  27.05   34115865
# 13 2019-11-20  27.06  28.40  26.9450  28.03   54075774
# 14 2019-11-21  28.67  29.60  28.5000  29.46   55658629
# 15 2019-11-22  29.84  30.13  29.2100  29.56   44383876
# ...

# %% [markdown]
# London bikes dataset

# %%
df=pd.read_csv('london_bike.csv')

# %%
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
df=df.set_index('timestamp')

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# ...

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0
