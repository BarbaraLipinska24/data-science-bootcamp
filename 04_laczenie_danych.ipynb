# %% [markdown]
# <a href="https://colab.research.google.com/github/BarbaraLipinska24/data-science-bootcamp/blob/main/04_laczenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

def fetch_financial_data(company='AMZN'):

    'This function fetch stock market quotations.'

    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

apple=fetch_financial_data('AAPL')
amazon=fetch_financial_data('AMZN')
google=fetch_financial_data('GOOGL')
uber=fetch_financial_data('UBER')

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1128 entries, 2023-10-31 to 2019-05-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1128 non-null   float64
#  1   High    1128 non-null   float64
#  2   Low     1128 non-null   float64
#  3   Close   1128 non-null   float64
#  4   Volume  1128 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 52.9 KB

# %%
apple.head()
# Out:
#               Open      High     Low   Close      Volume
# Date
# 2023-10-31  169.35  170.9000  167.90  170.77  44846017.0
# 2023-10-30  169.02  171.1700  168.87  170.29  51130955.0
# 2023-10-27  166.91  168.9600  166.83  168.22  58499129.0
# 2023-10-26  170.37  171.3775  165.67  166.89  70625258.0
# 2023-10-25  171.88  173.0600  170.65  171.10  57156962.0

# %% [markdown]
# Preprocessing

# %%
apple.columns=['apple_'+ col.lower() for col in apple.columns]
amazon.columns=['amazon_'+ col.lower() for col in amazon.columns]
google.columns=['google_'+ col.lower() for col in google.columns]
uber.columns=['uber_'+ col.lower() for col in uber.columns]

# %%
google.head()
# Out:
#             google_open  google_high  google_low  google_close  google_volume
# Date
# 2023-10-31       125.06     125.3700    122.6850        124.08       26292342
# 2023-10-30       123.21     125.4000    122.7500        124.46       28940081
# 2023-10-27       122.88     123.3100    120.2057        122.17       44566506
# 2023-10-26       123.27     124.3297    121.2700        122.28       57061140
# 2023-10-25       128.16     128.3100    125.0700        125.61       84366208

# %% [markdown]
# KONKATENACJA DANYCH

# %%
df=pd.concat(objs=[apple,amazon,google,uber],axis=1)

# %%
pd.set_option('display.float_format',lambda x: f'{x:.2f}')
df.describe()
# Out:
#        apple_apple_open  apple_apple_high  apple_apple_low  apple_apple_close  \
# count           1256.00           1256.00          1256.00            1256.00
# mean             117.36            118.74           116.07             117.46
# std               47.20             47.68            46.75              47.23
# min               34.74             35.16            34.26              34.31
# 25%               68.52             69.42            68.14              68.57
# 50%              130.44            131.77           128.69             130.35
# 75%              153.92            156.27           152.44             154.24
# max              196.24            198.23           195.28             196.45
#
#        apple_apple_volume  amazon_open  amazon_high  amazon_low  amazon_close  \
# count             1256.00      1256.00      1256.00     1256.00       1256.00
# mean         107428047.19       125.59       127.15      123.91        125.54
# std           56250788.68        32.20        32.48       31.83         32.11
# min           31458198.00        67.30        69.80       65.35         67.20
# 25%           70777250.13        94.06        95.17       92.99         94.15
# 50%           91909871.27       123.11       124.69      121.31        123.48
# 75%          127346489.85       158.34       159.95      156.25        158.10
# max          434708544.96       187.20       188.65      184.84        186.57
#
#        amazon_volume  google_open  google_high  google_low  google_close  \
# count        1256.00      1256.00      1256.00     1256.00       1256.00
# mean     78958487.93        95.55        96.65       94.50         95.60
# std      35850046.12        29.98        30.27       29.65         29.95
# min      17626740.00        49.22        50.61       48.88         49.23
# 25%      54894045.00        66.60        67.12       65.72         66.59
# 50%      67926679.00        95.45        97.03       94.20         95.61
# 75%      93114280.00       121.39       122.59      120.27        121.77
# max     311345660.00       151.25       151.55      148.90        149.84
#
#        google_volume  uber_open  uber_high  uber_low  uber_close  uber_volume
# count        1256.00    1128.00    1128.00   1128.00     1128.00      1128.00
# mean     34089863.26      37.71      38.46     36.91       37.69  24912203.65
# std      15123137.11       9.34       9.41      9.21        9.29  15973245.32
# min       9312760.00      15.96      17.80     13.71       14.82   3380003.00
# 25%      24550790.00      30.62      31.26     30.00       30.68  15674506.25
# 50%      30433432.50      35.97      36.73     35.12       35.98  21211108.50
# 75%      38420005.00      44.50      45.24     43.75       44.41  29481889.75
# max     133177100.00      63.25      64.05     60.80       63.18 186322536.00

# %%
df.corr()
# Out:
#                     apple_apple_open  apple_apple_high  apple_apple_low  \
# apple_apple_open                1.00              1.00             1.00
# apple_apple_high                1.00              1.00             1.00
# apple_apple_low                 1.00              1.00             1.00
# apple_apple_close               1.00              1.00             1.00
# apple_apple_volume             -0.49             -0.48            -0.50
# amazon_open                     0.58              0.58             0.58
# amazon_high                     0.59              0.59             0.59
# amazon_low                      0.58              0.58             0.58
# amazon_close                    0.58              0.58             0.58
# amazon_volume                  -0.33             -0.33            -0.34
# google_open                     0.90              0.90             0.91
# google_high                     0.91              0.91             0.91
# google_low                      0.90              0.90             0.90
# google_close                    0.90              0.90             0.91
# google_volume                  -0.09             -0.08            -0.09
# uber_open                       0.15              0.14             0.15
# uber_high                       0.15              0.15             0.15
# uber_low                        0.16              0.15             0.16
# uber_close                      0.15              0.15             0.16
# uber_volume                     0.04              0.05             0.04
#
#                     apple_apple_close  apple_apple_volume  amazon_open  \
# apple_apple_open                 1.00               -0.49         0.58
# apple_apple_high                 1.00               -0.48         0.58
# apple_apple_low                  1.00               -0.50         0.58
# apple_apple_close                1.00               -0.49         0.58
# apple_apple_volume              -0.49                1.00        -0.16
# amazon_open                      0.58               -0.16         1.00
# amazon_high                      0.59               -0.16         1.00
# amazon_low                       0.58               -0.17         1.00
# amazon_close                     0.58               -0.17         1.00
# amazon_volume                   -0.34                0.63        -0.18
# google_open                      0.90               -0.49         0.69
# google_high                      0.91               -0.49         0.69
# google_low                       0.90               -0.50         0.69
# google_close                     0.91               -0.49         0.69
# google_volume                   -0.09                0.45        -0.11
# uber_open                        0.15               -0.20         0.58
# uber_high                        0.15               -0.19         0.58
# uber_low                         0.16               -0.22         0.58
# uber_close                       0.15               -0.20         0.58
# uber_volume                      0.04                0.24        -0.03
#
#                     amazon_high  amazon_low  amazon_close  amazon_volume  \
# apple_apple_open           0.59        0.58          0.58          -0.33
# apple_apple_high           0.59        0.58          0.58          -0.33
# apple_apple_low            0.59        0.58          0.58          -0.34
# apple_apple_close          0.59        0.58          0.58          -0.34
# apple_apple_volume        -0.16       -0.17         -0.17           0.63
# amazon_open                1.00        1.00          1.00          -0.18
# amazon_high                1.00        1.00          1.00          -0.17
# amazon_low                 1.00        1.00          1.00          -0.19
# amazon_close               1.00        1.00          1.00          -0.18
# amazon_volume             -0.17       -0.19         -0.18           1.00
# google_open                0.69        0.69          0.69          -0.35
# google_high                0.69        0.68          0.69          -0.34
# google_low                 0.69        0.69          0.69          -0.35
# google_close               0.69        0.69          0.69          -0.35
# google_volume             -0.10       -0.12         -0.11           0.52
# uber_open                  0.57        0.59          0.58          -0.19
# uber_high                  0.57        0.59          0.58          -0.19
# uber_low                   0.57        0.59          0.58          -0.21
# uber_close                 0.57        0.59          0.58          -0.20
# uber_volume               -0.03       -0.04         -0.04           0.25
#
#                     google_open  google_high  google_low  google_close  \
# apple_apple_open           0.90         0.91        0.90          0.90
# apple_apple_high           0.90         0.91        0.90          0.90
# apple_apple_low            0.91         0.91        0.90          0.91
# apple_apple_close          0.90         0.91        0.90          0.91
# apple_apple_volume        -0.49        -0.49       -0.50         -0.49
# amazon_open                0.69         0.69        0.69          0.69
# amazon_high                0.69         0.69        0.69          0.69
# amazon_low                 0.69         0.68        0.69          0.69
# amazon_close               0.69         0.69        0.69          0.69
# amazon_volume             -0.35        -0.34       -0.35         -0.35
# google_open                1.00         1.00        1.00          1.00
# google_high                1.00         1.00        1.00          1.00
# google_low                 1.00         1.00        1.00          1.00
# google_close               1.00         1.00        1.00          1.00
# google_volume             -0.14        -0.13       -0.15         -0.14
# uber_open                  0.29         0.29        0.30          0.29
# uber_high                  0.29         0.29        0.30          0.29
# uber_low                   0.30         0.29        0.30          0.30
# uber_close                 0.29         0.29        0.30          0.30
# uber_volume                0.05         0.05        0.04          0.05
#
#                     google_volume  uber_open  uber_high  uber_low  uber_close  \
# apple_apple_open            -0.09       0.15       0.15      0.16        0.15
# apple_apple_high            -0.08       0.14       0.15      0.15        0.15
# apple_apple_low             -0.09       0.15       0.15      0.16        0.16
# apple_apple_close           -0.09       0.15       0.15      0.16        0.15
# apple_apple_volume           0.45      -0.20      -0.19     -0.22       -0.20
# amazon_open                 -0.11       0.58       0.58      0.58        0.58
# amazon_high                 -0.10       0.57       0.57      0.57        0.57
# amazon_low                  -0.12       0.59       0.59      0.59        0.59
# amazon_close                -0.11       0.58       0.58      0.58        0.58
# amazon_volume                0.52      -0.19      -0.19     -0.21       -0.20
# google_open                 -0.14       0.29       0.29      0.30        0.29
# google_high                 -0.13       0.29       0.29      0.29        0.29
# google_low                  -0.15       0.30       0.30      0.30        0.30
# google_close                -0.14       0.29       0.29      0.30        0.30
# google_volume                1.00      -0.17      -0.16     -0.18       -0.17
# uber_open                   -0.17       1.00       1.00      1.00        0.99
# uber_high                   -0.16       1.00       1.00      1.00        1.00
# uber_low                    -0.18       1.00       1.00      1.00        1.00
# uber_close                  -0.17       0.99       1.00      1.00        1.00
# uber_volume                  0.27      -0.22      -0.19     -0.24       -0.21
#
#                     uber_volume
# apple_apple_open           0.04
# apple_apple_high           0.05
# apple_apple_low            0.04
# apple_apple_close          0.04
# apple_apple_volume         0.24
# amazon_open               -0.03
# amazon_high               -0.03
# amazon_low                -0.04
# amazon_close              -0.04
# amazon_volume              0.25
# google_open                0.05
# google_high                0.05
# google_low                 0.04
# google_close               0.05
# google_volume              0.27
# uber_open                 -0.22
# uber_high                 -0.19
# uber_low                  -0.24
# uber_close                -0.21
# uber_volume                1.00

# %%
df.columns
# Out:
# Index(['apple_apple_open', 'apple_apple_high', 'apple_apple_low',
#        'apple_apple_close', 'apple_apple_volume', 'amazon_open', 'amazon_high',
#        'amazon_low', 'amazon_close', 'amazon_volume', 'google_open',
#        'google_high', 'google_low', 'google_close', 'google_volume',
#        'uber_open', 'uber_high', 'uber_low', 'uber_close', 'uber_volume'],
#       dtype='object')

# %%
closes=[col for col in df.columns if col.endswith('close')]
closes
# Out:
# ['apple_apple_close', 'amazon_close', 'google_close', 'uber_close']

# %%
df[closes].corr()
# Out:
#                    apple_apple_close  amazon_close  google_close  uber_close
# apple_apple_close               1.00          0.58          0.91        0.15
# amazon_close                    0.58          1.00          0.69        0.58
# google_close                    0.91          0.69          1.00        0.30
# uber_close                      0.15          0.58          0.30        1.00

# %% [markdown]
# Append

# %%
uber_6=uber[uber.index.month==6]

# %%
uber_6
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2023-06-30      43.11      43.43     42.92       43.17     17589240
# 2023-06-29      44.09      44.28     42.11       42.58     28595285
# 2023-06-28      43.50      45.24     43.32       44.24     28187374
# 2023-06-27      44.69      44.83     43.75       43.83     29652066
# 2023-06-26      43.75      45.04     43.68       44.42     33692974
# ...               ...        ...       ...         ...          ...
# 2019-06-07      44.92      45.67     44.13       44.16     12654670
# 2019-06-06      45.00      45.75     44.28       44.92     16403691
# 2019-06-05      42.87      45.66     42.50       45.00     28609604
# 2019-06-04      42.56      42.88     40.70       42.75     23432141
# 2019-06-03      40.74      41.85     40.24       41.25     16605261
#
# [106 rows x 5 columns]

# %%
uber_7=uber[uber.index.month==7]
uber_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2023-07-31      48.85      49.49     48.15       49.46     38736789
# 2023-07-28      47.14      48.43     46.71       48.14     17154631
# 2023-07-27      48.00      48.09     46.35       46.61     17991953
# 2023-07-26      47.05      47.55     46.62       47.31     16666161
# 2023-07-25      47.20      47.73     46.93       47.17     14188200
# ...               ...        ...       ...         ...          ...
# 2019-07-08      43.59      43.85     42.75       42.95      9304101
# 2019-07-05      44.31      44.55     43.01       43.53      8239452
# 2019-07-03      44.00      44.46     43.79       44.23      3380003
# 2019-07-02      44.55      44.68     43.75       44.00     11881274
# 2019-07-01      46.98      47.04     44.06       44.27     17739998
#
# [105 rows x 5 columns]

# %%
uber_6_7=uber_6.append(uber_7)
# Out:
# <ipython-input-30-11150a435688>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   uber_6_7=uber_6.append(uber_7)
